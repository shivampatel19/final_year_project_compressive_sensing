# %%
import cv2

def resize_image(image, target_height=237, target_width=374):
    """
    Resize an image to the specified dimensions while handling padding for shrinking or zooming.
    
    Args:
    - image: Input image as a numpy array.
    - target_height: Target height for resizing.
    - target_width: Target width for resizing.
    
    Returns:
    - Resized image as a numpy array with dimensions (target_height, target_width, 3).
    """
    # Get the original dimensions of the image
    original_height, original_width, _ = image.shape
    
    # Calculate scaling factors for resizing
    scale_height = target_height / original_height
    scale_width = target_width / original_width
    
    # Decide whether to shrink or zoom the image based on scaling factors
    if scale_height < 1 or scale_width < 1:
        # Shrink the image by adding padding
        new_height = min(target_height, original_height)
        new_width = min(target_width, original_width)
        resized_image = cv2.resize(image, (new_width, new_height), interpolation=cv2.INTER_AREA)
        
        # Add padding to match the target dimensions
        top_padding = (target_height - new_height) // 2
        bottom_padding = target_height - new_height - top_padding
        left_padding = (target_width - new_width) // 2
        right_padding = target_width - new_width - left_padding
        resized_image = cv2.copyMakeBorder(resized_image, top_padding, bottom_padding, left_padding, right_padding, cv2.BORDER_CONSTANT, value=(0, 0, 0))
    else:
        # Zoom the image by adding padding
        new_height = max(target_height, original_height)
        new_width = max(target_width, original_width)
        resized_image = cv2.resize(image, (new_width, new_height), interpolation=cv2.INTER_CUBIC)
        
        # Crop the image to match the target dimensions
        start_x = (new_width - target_width) // 2
        start_y = (new_height - target_height) // 2
        resized_image = resized_image[start_y:start_y + target_height, start_x:start_x + target_width]
    
    return resized_image

# Example usage:
# Load an image using OpenCV
# img = cv2.imread("image.jpg")
# Resize the image
# resized_img = resize_image(img, target_height=237, target_width=374)

# %%
import cv2

def restore_image(image, original_height, original_width):
    """
    Restore an image to its original dimensions from a resized image.
    
    Args:
    - image: Resized image as a numpy array.
    - original_height: Original height of the image.
    - original_width: Original width of the image.
    
    Returns:
    - Restored image as a numpy array with dimensions (original_height, original_width, 3).
    """
    # Get the dimensions of the resized image
    resized_height, resized_width, _ = image.shape
    
    # Calculate the scaling factors for zooming or shrinking
    scale_height = original_height / resized_height
    scale_width = original_width / resized_width
    
    # Decide whether to zoom or shrink the image based on scaling factors
    if scale_height < 1 or scale_width < 1:
        # Zoom the image by merging pixels
        restored_image = cv2.resize(image, (original_width, original_height), interpolation=cv2.INTER_CUBIC)
    else:
        # Shrink the image by adding new pixels
        restored_image = cv2.resize(image, (original_width, original_height), interpolation=cv2.INTER_AREA)
    
    return restored_image

# Example usage:
# original_height, original_width = 1707, 2560
# restored_img = restore_image(resized_img, original_height, original_width)

# %%
img = cv2.imread("robot.jpg")

resized_img = resize_image(img, target_height=237, target_width=374)
plt.imshow(resized_img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4556/914396890.py in <module>
#       2
#       3 resized_img = resize_image(img, target_height=237, target_width=374)
# ----> 4 plt.imshow(resized_img)
#
# NameError: name 'plt' is not defined

# %%
restored_img = restore_image(resized_img, img.shape[0], img.shape[1])
plt.imshow(restored_img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4556/2233698077.py in <module>
#       1 restored_img = restore_image(resized_img, img.shape[0], img.shape[1])
# ----> 2 plt.imshow(restored_img)
#
# NameError: name 'plt' is not defined

# %%
resized_img.shape
# Out:
# (237, 374, 3)

# %%
img.shape
# Out:
# (740, 740, 3)

# %%
# Load the image using OpenCV
image = cv2.imread('flower.jpg')

# Convert the image from BGR to RGB (matplotlib uses RGB)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the image using plt.imshow()
plt.imshow(image_rgb)
plt.axis('off')  # Turn off axis
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4556/964304575.py in <module>
#       6
#       7 # Display the image using plt.imshow()
# ----> 8 plt.imshow(image_rgb)
#       9 plt.axis('off')  # Turn off axis
#      10 plt.show()
#
# NameError: name 'plt' is not defined

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !ls

# %%
#import os
#os.chdir("drive/My Drive/Final year Project/")

# %%
import os
import re
import cv2
import torch
import torchvision
import pandas as pd
import numpy as np
from PIL import Image
from tqdm import tqdm
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
from TrainDataset import TrainDataset
from TestDataset import TestDataset
#from model import ReconNet
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import matplotlib.pyplot as plt
import matplotlib.pyplot as pyplot
# %matplotlib inline

# %%
# This is the path of the BSDS200 dataset
# The Berkeley Segmentation Dataset and Benchmark (BSDS 500 or BSDS 200) is a dataset
# and evaluation benchmark widely used in the computer vision community for the task of image segmentation.
# path = './images/all_images/BSDS200'

# %%
# # This code shows 9 random images from the BSDS200 data in a 3*3 matrix.
# fig, axes = plt.subplots(3, 3, figsize = (12,12))
# for row in axes:
#   for axe in row:
#       index = np.random.randint(len(os.listdir(path)))
#       img_name = os.listdir(path)[index]
#       img = plt.imread(os.path.join(path, img_name))
#       # lbl = img_name.rsplit('_',1)[0]
#       axe.imshow(img)
#       # axe.set_title(lbl)
#       axe.set_axis_off()

# %%
path = './images/all_images/BSDS200'
compression_percentage = 10
compression_rate = compression_percentage/100
file_number = '07'
test_file_name = 'test1.png'

# %%
test_img = plt.imread('./images/' + test_file_name)
plt.imshow(test_img)

# %%
test_img.shape
# Out:
# (237, 374, 3)

# %%
#Phi measurment matrices.
# These matrices are likely designed to be sparse or structured in a way
# that allows for a compact representation of the signal.
os.listdir('./phi')
# Out:
# ['phi_0_01_1089.mat',
#  'phi_0_04_1089.mat',
#  'phi_0_10_1089.mat',
#  'phi_0_25_1089.mat']

# %%
import scipy.io

# We will use the phi_0_25_1089.mat file, the file has a compression ratio of 0.25 and has a dimension of 1089.
# We will be using this because it has a higher compression ratio.
mat = scipy.io.loadmat('./phi/phi_0_' + str(compression_percentage) + '_1089.mat')['phi']

# %%
mat = torch.from_numpy(mat)
mat
# Out:
# tensor([[-0.0826, -0.0518, -0.0060,  ..., -0.0517, -0.0347,  0.0207],
#         [ 0.0367, -0.0378,  0.0138,  ...,  0.0210, -0.0126, -0.0211],
#         [-0.0328,  0.0143,  0.0149,  ..., -0.0354,  0.0012, -0.0176],
#         ...,
#         [-0.0024, -0.0335,  0.0236,  ...,  0.0068, -0.0671,  0.0063],
#         [ 0.0901,  0.0124, -0.0432,  ..., -0.0132, -0.0288, -0.0460],
#         [-0.0111,  0.0539, -0.0312,  ..., -0.0039,  0.0364,  0.0033]],
#        dtype=torch.float64)

# %%
mat.size()
# Out:
# torch.Size([109, 1089])

# %% [markdown]
# #DataLoader

# %%
#The train dataset images are compressed and divided into blocks and converted into pytorch tensor.
transformations = transforms.Compose([transforms.ToTensor()])
train_data = TrainDataset(path,mat,transformations,compression_rate)

# %%
train_data.__len__()
# Out:
# 138600

# %%
train_data.__getitem__(0)
# Out:
# (tensor([-0.0097,  0.1711,  0.2732, -0.1390,  0.1444, -0.0520, -0.2903, -0.2603,
#          -0.4910, -0.4897, -0.1077,  0.0359, -0.0390,  0.1140,  0.0458, -0.1206,
#           0.1763,  0.0420,  0.0889, -0.2637, -0.2290,  0.1142, -0.2730, -0.3016,
#           0.2968,  0.2102, -0.1045, -0.2378, -0.2858,  0.3281, -0.0904,  0.0328,
#           0.0202, -0.3440,  0.1143,  0.3128,  0.0827,  0.1889,  0.2518, -0.0896,
#          -0.2046, -0.0863, -0.2292, -0.1303,  0.0734, -0.0599,  0.4120, -0.1689,
#          -0.1865, -0.0012,  0.0059, -0.1791,  0.2953, -0.2035,  0.1384, -0.1846,
#           0.1563, -0.1143, -0.2319, -0.4016, -0.0972,  0.0168,  0.0185,  0.0466,
#          -0.0678,  0.3519,  0.0013, -0.2314,  0.1163, -0.1148,  0.0446, -0.3208,
#           0.3622,  0.3776, -0.2498, -0.0589, -0.0234,  0.0085,  0.0708,  0.3957,
#          -0.2543,  0.0903,  0.1074,  0.3348,  0.0153, -0.0508, -0.0751,  0.1163,
#          -0.0201,  0.0113, -0.1462, -0.3658,  0.0707,  0.0661,  0.1346,  0.0865,
#           0.2897, -0.3685, -0.2861, -0.3429, -0.0197,  0.1809, -0.0643,  0.2143,
#          -0.1443,  0.0626, -0.0204, -0.1216, -0.1070], dtype=torch.float64),
#  tensor([0.1238, 0.1530, 0.1498,  ..., 0.1650, 0.1649, 0.1360],
#         dtype=torch.float64))

# %%
train_data.__getitem__(0)[0].size()
# Out:
# torch.Size([109])

# %%
#plt.imshow(train_data.__getitem__(0)[0].view(17,16))

# %%
train_dl = DataLoader(train_data,batch_size=128)

# %%
print("No of Batches -",len(train_dl))
# Out:
# No of Batches - 1083

# %%
train_iter = iter(train_dl)
print(type(train_iter))

#images are the compressed images, and labels are the original images, compression ratio - 0.25 is used.
#images , labels = train_iter.next()
images , labels = next(train_iter)
print('Images shape on batch size = {}'.format(images.size()))
print('Labels shape on batch size = {}'.format(labels.size()))
# Out:
# <class 'torch.utils.data.dataloader._SingleProcessDataLoaderIter'>
# Images shape on batch size = torch.Size([128, 109])
# Labels shape on batch size = torch.Size([128, 1089])

# %%
# Checking for availability of GPU

use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
print(device)
# Out:
# cuda:0

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F
# from math import ceil

# class Model(nn.Module):
#     def __init__(self, measurement_rate=0.25):
#         super(Model, self).__init__()

#         self.measurement_rate = measurement_rate
#         self.fc1 = nn.Linear(ceil(self.measurement_rate * 1089), 500)
#         nn.init.normal_(self.fc1.weight, mean=0, std=0.1)
        
#         self.fc2 = nn.Linear(500, 1089)  # Introduction of dense layer for sparse representation learning
#         nn.init.normal_(self.fc2.weight, mean=0, std=0.1)
        
#         self.conv1 = nn.Conv2d(1, 32, 7, 1, padding=3)
#         nn.init.normal_(self.conv1.weight, mean=0, std=0.1)
        
#         self.conv2 = nn.Conv2d(32, 32, 3, 1, padding=1)
#         nn.init.normal_(self.conv2.weight, mean=0, std=0.1)
        
#         self.conv3 = nn.Conv2d(32, 16, 3, 1, padding=1)
#         nn.init.normal_(self.conv3.weight, mean=0, std=0.1)

#         self.conv4 = nn.Conv2d(16, 16, 3, 1, padding=1)
#         nn.init.normal_(self.conv4.weight, mean=0, std=0.1)

#         self.conv5 = nn.Conv2d(16, 8, 3, 1, padding=1)
#         nn.init.normal_(self.conv5.weight, mean=0, std=0.1)

#         self.conv6 = nn.Conv2d(8, 1, 3, 1, padding=1)
#         nn.init.normal_(self.conv6.weight, mean=0, std=0.1)

#     def forward(self, x):
#         # Sparse representation learning
#         x = F.relu(self.fc1(x))
#         x = F.relu(self.fc2(x))
#         x = x.view(-1, 33, 33)
#         x = x.unsqueeze(1)
        
#         # Convolutional layers for feature extraction
#         x = F.relu(self.conv1(x))
#         x = F.relu(self.conv2(x))
#         x = F.relu(self.conv3(x))
#         x = F.relu(self.conv4(x))
#         x = F.relu(self.conv5(x))
        
#         # Reconstruction layer
#         x = self.conv6(x)

#         return x

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F
# from math import ceil

# class Model(nn.Module):
#     def __init__(self, measurement_rate=0.25):
#         super(Model, self).__init__()

#         self.measurement_rate = measurement_rate
#         self.fc1 = nn.Linear(ceil(self.measurement_rate * 1089), 500)
#         self.fc2 = nn.Linear(500, 1089)  # Introduction of dense layer for sparse representation learning

#         self.conv1 = nn.Conv2d(1, 32, 7, 1, padding=3)
#         self.conv2 = nn.Conv2d(32, 32, 3, 1, padding=1)
#         self.conv3 = nn.Conv2d(32, 16, 3, 1, padding=1)
#         self.conv4 = nn.Conv2d(16, 16, 3, 1, padding=1)
#         self.conv5 = nn.Conv2d(16, 8, 3, 1, padding=1)
#         self.conv6 = nn.Conv2d(8, 1, 3, 1, padding=1)

#         self.dropout = nn.Dropout2d(p=0.2)
#         self.leaky_relu = nn.LeakyReLU(0.2)

#     def forward(self, x):
#         # Sparse representation learning
#         x = F.relu(self.fc1(x))
#         x = F.relu(self.fc2(x))
#         x = x.view(-1, 33, 33)
#         x = x.unsqueeze(1)
        
#         # Convolutional layers for feature extraction
#         x = self.leaky_relu(self.conv1(x))
#         x = self.leaky_relu(self.conv2(x))
#         x = self.leaky_relu(self.conv3(x))
#         x = self.dropout(x)
#         x = self.leaky_relu(self.conv4(x))
#         x = self.leaky_relu(self.conv5(x))
        
#         # Reconstruction layer
#         x = self.conv6(x)

#         return x

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F
# from math import ceil

# class Model(nn.Module):
#     def __init__(self, measurement_rate=0.25):
#         super(Model, self).__init__()

#         # Define the measurement rate for sparse representation
#         self.measurement_rate = measurement_rate

#         # Fully connected layers
#         self.fc1 = nn.Linear(ceil(self.measurement_rate * 1089), 500)
#         nn.init.normal_(self.fc1.weight, mean=0, std=0.1)  # Initialize weights
#         self.fc2 = nn.Linear(500, 1089)
#         nn.init.normal_(self.fc2.weight, mean=0, std=0.1)  # Initialize weights

#         # Convolutional layers
#         self.conv1 = nn.Conv2d(1, 32, 7, 1, padding=3)
#         nn.init.normal_(self.conv1.weight, mean=0, std=0.1)  # Initialize weights
#         self.bn1 = nn.BatchNorm2d(32)  # Batch Normalization
#         self.conv2 = nn.Conv2d(32, 32, 3, 1, padding=1)
#         nn.init.normal_(self.conv2.weight, mean=0, std=0.1)  # Initialize weights
#         self.bn2 = nn.BatchNorm2d(32)  # Batch Normalization
#         self.conv3 = nn.Conv2d(32, 16, 3, 1, padding=1)
#         nn.init.normal_(self.conv3.weight, mean=0, std=0.1)  # Initialize weights
#         self.bn3 = nn.BatchNorm2d(16)  # Batch Normalization
#         self.conv4 = nn.Conv2d(16, 16, 3, 1, padding=1)
#         nn.init.normal_(self.conv4.weight, mean=0, std=0.1)  # Initialize weights
#         self.bn4 = nn.BatchNorm2d(16)  # Batch Normalization
#         self.conv5 = nn.Conv2d(16, 8, 3, 1, padding=1)
#         nn.init.normal_(self.conv5.weight, mean=0, std=0.1)  # Initialize weights
#         self.bn5 = nn.BatchNorm2d(8)  # Batch Normalization
#         self.conv6 = nn.Conv2d(8, 1, 3, 1, padding=1)
#         nn.init.normal_(self.conv6.weight, mean=0, std=0.1)  # Initialize weights

#         # Dropout and activation function
#         self.dropout = nn.Dropout2d(p=0.2)
#         self.leaky_relu = nn.LeakyReLU(0.2)

#     def forward(self, x):
#         # Sparse representation learning
#         x = F.relu(self.fc1(x))
#         x = F.relu(self.fc2(x))
#         x = x.view(-1, 33, 33)
#         x = x.unsqueeze(1)
        
#         # Convolutional layers for feature extraction
#         x = self.leaky_relu(self.bn1(self.conv1(x)))
#         x = self.leaky_relu(self.bn2(self.conv2(x)))
#         x = self.leaky_relu(self.bn3(self.conv3(x)))
#         x = self.dropout(x)
#         x = self.leaky_relu(self.bn4(self.conv4(x)))
#         x = self.leaky_relu(self.bn5(self.conv5(x)))
        
#         # Reconstruction layer
#         x = self.conv6(x)

#         return x

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F
# from math import ceil

# class Model(nn.Module):
#     def __init__(self, measurement_rate=0.25):
#         super(Model, self).__init__()

#         # Define the measurement rate for sparse representation
#         self.measurement_rate = measurement_rate

#         # Fully connected layers
#         self.fc1 = nn.Linear(ceil(self.measurement_rate * 1089), 500)
#         nn.init.xavier_normal_(self.fc1.weight)  # Xavier normal initialization
#         self.fc2 = nn.Linear(500, 1089)
#         nn.init.xavier_normal_(self.fc2.weight)  # Xavier normal initialization

#         # Convolutional layers
#         self.conv1 = nn.Conv2d(1, 32, 7, 1, padding=3)
#         nn.init.xavier_normal_(self.conv1.weight)  # Xavier normal initialization
#         self.bn1 = nn.BatchNorm2d(32)  # Batch Normalization
#         self.conv2 = nn.Conv2d(32, 32, 3, 1, padding=1)
#         nn.init.xavier_normal_(self.conv2.weight)  # Xavier normal initialization
#         self.bn2 = nn.BatchNorm2d(32)  # Batch Normalization
#         self.conv3 = nn.Conv2d(32, 16, 3, 1, padding=1)
#         nn.init.xavier_normal_(self.conv3.weight)  # Xavier normal initialization
#         self.bn3 = nn.BatchNorm2d(16)  # Batch Normalization
#         self.conv4 = nn.Conv2d(16, 16, 3, 1, padding=1)
#         nn.init.xavier_normal_(self.conv4.weight)  # Xavier normal initialization
#         self.bn4 = nn.BatchNorm2d(16)  # Batch Normalization
#         self.conv5 = nn.Conv2d(16, 8, 3, 1, padding=1)
#         nn.init.xavier_normal_(self.conv5.weight)  # Xavier normal initialization
#         self.bn5 = nn.BatchNorm2d(8)  # Batch Normalization
#         self.conv6 = nn.Conv2d(8, 1, 3, 1, padding=1)
#         nn.init.xavier_normal_(self.conv6.weight)  # Xavier normal initialization

#         # Dropout and activation function
#         self.dropout = nn.Dropout2d(p=0.2)
#         self.leaky_relu = nn.LeakyReLU(0.2)

#     def forward(self, x):
#         # Sparse representation learning
#         x = F.relu(self.fc1(x))
#         x = F.relu(self.fc2(x))
#         x = x.view(-1, 33, 33)
#         x = x.unsqueeze(1)
        
#         # Convolutional layers for feature extraction
#         x = self.leaky_relu(self.bn1(self.conv1(x)))
#         x = self.leaky_relu(self.bn2(self.conv2(x)))
#         x = self.leaky_relu(self.bn3(self.conv3(x)))
#         x = self.dropout(x)
#         x = self.leaky_relu(self.bn4(self.conv4(x)))
#         x = self.leaky_relu(self.bn5(self.conv5(x)))
        
#         # Reconstruction layer
#         x = self.conv6(x)

#         return x

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from math import ceil

class Model(nn.Module):
    def __init__(self, measurement_rate=0.25):
        super(Model, self).__init__()

        self.measurement_rate = measurement_rate
        
        # Fully connected layers
        self.fc1 = nn.Linear(ceil(self.measurement_rate * 1089), 500)
        nn.init.xavier_normal_(self.fc1.weight)
        
        self.fc2 = nn.Linear(500, 1089)
        nn.init.xavier_normal_(self.fc2.weight)
        
        # Dropout layer
        self.dropout = nn.Dropout(p=0.2)
        
        # Convolutional layers
        self.conv1 = nn.Conv2d(1, 32, 7, 1, padding=3)
        nn.init.xavier_normal_(self.conv1.weight)
        
        self.conv2 = nn.Conv2d(32, 32, 3, 1, padding=1)
        nn.init.xavier_normal_(self.conv2.weight)
        
        self.conv3 = nn.Conv2d(32, 16, 3, 1, padding=1)
        nn.init.xavier_normal_(self.conv3.weight)

        self.conv4 = nn.Conv2d(16, 16, 3, 1, padding=1)
        nn.init.xavier_normal_(self.conv4.weight)

        self.conv5 = nn.Conv2d(16, 8, 3, 1, padding=1)
        nn.init.xavier_normal_(self.conv5.weight)

        self.conv6 = nn.Conv2d(8, 1, 3, 1, padding=1)
        nn.init.xavier_normal_(self.conv6.weight)

    def forward(self, x):
        # Sparse representation learning
        x = F.relu(self.fc1(x))
        x = self.dropout(x)  # Applying dropout
        x = F.relu(self.fc2(x))
        x = x.view(-1, 33, 33)
        x = x.unsqueeze(1)
        
        # Convolutional layers for feature extraction
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = F.relu(self.conv5(x))
        
        # Reconstruction layer
        x = self.conv6(x)

        return x

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from math import ceil

class Model(nn.Module):
    def __init__(self, measurement_rate=0.25):
        super(Model, self).__init__()

        self.measurement_rate = measurement_rate
        
        # Fully connected layers
        self.fc1 = nn.Linear(ceil(self.measurement_rate * 1089), 500)
        nn.init.xavier_normal_(self.fc1.weight)
        
        self.fc2 = nn.Linear(500, 1089)
        nn.init.xavier_normal_(self.fc2.weight)
        
        # Dropout layer
        self.dropout = nn.Dropout(p=0.2)
        
        # Convolutional layers
        self.conv1 = nn.Conv2d(1, 32, 7, 1, padding=3)
        nn.init.xavier_normal_(self.conv1.weight)
        
        self.conv2 = nn.Conv2d(32, 32, 3, 1, padding=1)
        nn.init.xavier_normal_(self.conv2.weight)
        
        self.conv3 = nn.Conv2d(32, 16, 3, 1, padding=1)
        nn.init.xavier_normal_(self.conv3.weight)

        self.conv4 = nn.Conv2d(16, 16, 3, 1, padding=1)
        nn.init.xavier_normal_(self.conv4.weight)

        self.conv5 = nn.Conv2d(16, 8, 3, 1, padding=1)
        nn.init.xavier_normal_(self.conv5.weight)

        self.conv6 = nn.Conv2d(8, 1, 3, 1, padding=1)
        nn.init.xavier_normal_(self.conv6.weight)

    def forward(self, x):
        # Sparse representation learning
        x = x.view(-1, ceil(self.measurement_rate * 1089))  # Flatten input
        x = F.relu(self.fc1(x))
        x = self.dropout(x)  # Applying dropout
        x = F.relu(self.fc2(x))
        x = x.view(-1, 33, 33)  # Reshape output to match the expected shape
        
        # Adding channel dimension
        x = x.unsqueeze(1)
        
        # Convolutional layers for feature extraction
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = F.relu(self.conv5(x))
        
        # Reconstruction layer
        x = self.conv6(x)

        return x

# %%
model = Model(measurement_rate=compression_rate)
model = nn.DataParallel(model)
model = model.cuda()

# %%
criterion = nn.MSELoss()
criterion = criterion.cuda()

# %%
# Adam Optimizer
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# inp (images) - is the compressed file
# label (labels) - is the original file
# The compressed image size, in the context of compressive sensing,
# usually refers to a reduced set of measurements or features that represent the original image.
# The goal of compressive sensing is to represent the image using fewer measurements than the number
# of pixels in the original image.

# %%
import torch
import time
import numpy as np

total_start_time = time.time()

def train(model, criterion, optimizer, train_dl, num_epochs=10, scheduler=None):
    for epoch in range(num_epochs):
        start_time = time.time()
        train_loss = []
        model.train()
        
        # Move model to CUDA device
        model = model.cuda()
        
        for inp, lbl in train_dl:
            inp = inp.cuda().float()
            lbl = lbl.cuda().float()

            optimizer.zero_grad()
            out = model(inp)
            out = out.view(lbl.size())
            loss = criterion(out, lbl)
            loss.backward()
            optimizer.step()

            train_loss.append(loss.item())

        epoch_time = time.time() - start_time
        total_time = time.time() - total_start_time  # Total time taken for all epochs so far

        print(f'Epoch: {epoch+1}, Training Loss: {np.mean(train_loss)}, Time taken: {epoch_time:.2f} seconds, Total time taken: {total_time:.2f} seconds')

        # Learning rate scheduler
        if scheduler:
            scheduler.step()

        
from torch.optim.lr_scheduler import StepLR

# Define your scheduler
scheduler = StepLR(optimizer, step_size=5, gamma=0.1)

# Pass the scheduler to train function
train(model, criterion, optimizer, train_dl, num_epochs=10)
# Out:
# Epoch: 1, Training Loss: 0.008522914947706704, Time taken: 33.67 seconds, Total time taken: 33.67 seconds
# Epoch: 2, Training Loss: 0.008078562642714449, Time taken: 33.72 seconds, Total time taken: 67.38 seconds
# Epoch: 3, Training Loss: 0.007361133911913809, Time taken: 33.88 seconds, Total time taken: 101.27 seconds
# Epoch: 4, Training Loss: 0.007276378913412975, Time taken: 33.96 seconds, Total time taken: 135.22 seconds
# Epoch: 5, Training Loss: 0.007352071599762875, Time taken: 33.85 seconds, Total time taken: 169.07 seconds
# Epoch: 6, Training Loss: 0.007089434107471024, Time taken: 33.97 seconds, Total time taken: 203.05 seconds
# Epoch: 7, Training Loss: 0.006963166649953079, Time taken: 34.15 seconds, Total time taken: 237.20 seconds
# Epoch: 8, Training Loss: 0.0071397358138981255, Time taken: 34.55 seconds, Total time taken: 271.74 seconds
# Epoch: 9, Training Loss: 0.0069511133114417535, Time taken: 34.47 seconds, Total time taken: 306.22 seconds
# Epoch: 10, Training Loss: 0.006922733584918307, Time taken: 34.13 seconds, Total time taken: 340.35 seconds

# %%
import os
cwd = os.getcwd()
print("Current working directory:", cwd)
# Out:
# Current working directory: /home/shivam/Desktop/final year project/final-year-project

# %%
model_name = 'model_state_new_' + file_number + '_lastest.pth'

# %%
torch.save(model.state_dict(), model_name)

# %%
state_dict = torch.load(model_name,map_location ='cpu')

# %%
model.load_state_dict(state_dict)
model.eval()
# Out:
# DataParallel(
#   (module): Model(
#     (fc1): Linear(in_features=109, out_features=500, bias=True)
#     (fc2): Linear(in_features=500, out_features=1089, bias=True)
#     (dropout): Dropout(p=0.2, inplace=False)
#     (conv1): Conv2d(1, 32, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv3): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv4): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv5): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv6): Conv2d(8, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )

# %% [markdown]
# #Reconstructing Test Image

# %%
test_img = plt.imread('./images/' + test_file_name)
test_img.shape
# Out:
# (237, 374, 3)

# %%
# Original Image
plt.imshow(test_img)

# %%
image_blocks = []
test_img = cv2.cvtColor(test_img, cv2.COLOR_BGR2YCR_CB)
test_img = cv2.normalize(test_img, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)
test_img = test_img[:,:,0]
h,w = test_img.shape
stride = 14
filter_size = 33
h_n = ((h - filter_size) // stride) + 1
w_n = ((w - filter_size) // stride) + 1

for i in range(h_n):
  for j in range(w_n):
    blocks = test_img[i*stride:(i*stride)+filter_size, j*stride:(j*stride)+filter_size]
    image_blocks.append(blocks)

image_blocks = np.array(image_blocks)

# %%
image_blocks.shape
# Out:
# (375, 33, 33)

# %%
# Processed Image
plt.imshow(test_img)

# Save the image
from matplotlib import pyplot

pyplot.savefig('./images/test_sample_' + file_number + '.png', bbox_inches='tight')

# %%
test_data = TestDataset(image_blocks,mat,transformations,compression_rate)

# %%
test_dl = DataLoader(test_data,1089)

# %%
model.load_state_dict(torch.load(model_name, map_location='cpu'))
# Out:
# <All keys matched successfully>

# %%
# Model Output
inp,lbl = next(iter(test_dl))
inp = inp.cuda()
lbl = lbl.cuda()
inp = inp.float()
lbl = lbl.float()

out = model(inp)
out = out.cuda()
out = out.view(lbl.size())
loss = criterion(out,lbl)
print('Test Loss',loss.item())
# Out:
# Test Loss 0.010527748614549637

# %%
out = out.view(-1,33,33)
out.size()
# Out:
# torch.Size([375, 33, 33])

# %%
out = out.cpu()
out = out.detach().numpy()

# %%
# Reconstruct the image
h,w = test_img.shape
recon_img = np.zeros((h,w))

k = 0
for i in range(h_n):
  for j in range(w_n):
    recon_img[i*stride:(i*stride)+filter_size, j*stride:(j*stride)+filter_size] = out[k]
    k += 1

# %%
# Reconstructed Image
plt.imshow(recon_img)

# Save the image
from matplotlib import pyplot

pyplot.savefig('./images/sample_result_' + file_number + '.png', bbox_inches='tight')

# %%
plt.imshow(test_img)

# %%
import numpy as np

def psnr(img1, img2):
    mse = np.mean((img1 - img2) ** 2)
    if mse == 0:
        return float('inf')
    PIXEL_MAX = 255.0  # Assuming pixel values are in the range [0, 255]
    return 20 * np.log10(PIXEL_MAX / np.sqrt(mse))

# %%
import cv2
original_image = cv2.imread('./images/test_sample_' + file_number + '.png')

# %%
decompressed_image = cv2.imread('./images/sample_result_' + file_number + '.png')

# %%
psnr(original_image, decompressed_image)
# Out:
# 30.92986868532657

# %%
psnr(original_image, decompressed_image)
# Out:
# 30.92986868532657

# %%
original_image = cv2.imread('./images/test_sample_25.png')
decompressed_image = cv2.imread('./images/sample_result_25.png')
psnr(original_image, decompressed_image)
# Out:
# 30.785354933442125
